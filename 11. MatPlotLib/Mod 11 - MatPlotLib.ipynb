# %% [markdown]
# # Mod 11 - MatPlotLib
#
# Plotting library. Pyplot most used - similar to MATLAB but uses Python

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# setting a style aestehtic for figures
plt.style.use('classic')

# %%
plt.plot([1,2,3,4],[1,4,9,16]) #passing 2 arrays; 1st on x, 2nd on y
plt.show()

# %%
x = np.linspace(0, 10, 100) #x start, x end, 
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show() # use once per python program and at end

# %% [markdown]
# #### In Jupyer Notebook
#
# Commands to plot - only once at top
#
# %matplotlib will lead to interactive plots
#
# %matplotlibinline will lead to static plots

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# #### Saving Figures to File
#
# Can save figures using savefig() command

# %%
fig.savefig('my_figure.png') #creates file in current working directory

# %%
from IPython.display import Image #need this to access pics
Image('my_figure.png')

# %%
#list of file types available
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ### Back to making plots

# %%
plt.plot([1,2,3,4],[1,4,9,16],"go") #g for green, o for circles
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("First plot")
# Out:
# Text(0.5, 1.0, 'First plot')

# %% [markdown]
# # Simple Line Plots

# %%
# set up
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
# start with figure and axes
fig = plt.figure() # container that contains everything in graph
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# ## Adjusting Plot: Line Colrs and Stles

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk) rgb / Cyan Magenta Yellow blacK
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
# shorthand
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# ## Adjusting the Plot: Axes Limits
#
# Not as necessary bc Matplotlib will find default to contain all your data
#
# most basic is with plt.xlim() and plt.ylim()

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
# display axis to be in reverse by changing order of args
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]); #[xmin, xmax, ymin, ymax]

# %%
plt.plot(x, np.sin(x))
plt.axis('tight'); #tightens bounds

# %%
plt.plot(x, np.sin(x))
plt.axis('equal'); #aspect ratio; 1 unit in x = to 1 unit in y

# %% [markdown]
# ## Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend(); # creates legend for you

# %% [markdown]
# ## Aside: Matplotlib Gotchas
#
# Transitioning between MATLAB-style to obj-oriented methods:
#
# - plt.xlabel() -> ax.set_xlabel()
# - plt.ylabel() → ax.set_ylabel()
# - plt.xlim() → ax.set_xlim()
# - plt.ylim() → ax.set_ylim()
# - plt.title() → ax.set_title()

# %%
# object oriented plotting. use ax.set()
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# # Simple Scatter Plots
#
# Third arg in function call is a char and rep type of symbol for plotting

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='blue');

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
#using multiple character codes to connect lines
plt.plot(x, y, '-ok');

# %%
# more customizations!
plt.plot(x, y, '-p', color='red',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ## Scatter Plots with plt.scatter

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.4,
            cmap='viridis') #ALPHA CHANGES TRANSPARENCY
plt.colorbar();  # show color scale

# %%
#sklearn gives dataset
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# # Visualizing errors
#
# Use errorbars

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
# making error bars lighter
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0);

# %% [markdown]
# ### Continuous Errors
#
# use plt.fill_between for greyscale

# %%
from sklearn.gaussian_process import GaussianProcess

# define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

# Compute the Gaussian process fit
gp = GaussianProcess(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1E-1,
                     random_start=100)
gp.fit(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10, 1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis], eval_MSE=True)
dyfit = 2 * np.sqrt(MSE)  # 2*sigma ~ 95% confidence region
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-75-0aeb76e3f6ca> in <module>
# ----> 1 from sklearn.gaussian_process import GaussianProcess
#       2
#       3 # define the model and draw some data
#       4 model = lambda x: x * np.sin(x)
#       5 xdata = np.array([1, 3, 5, 6, 8])
#
# ImportError: cannot import name 'GaussianProcess' from 'sklearn.gaussian_process' (/Users/Manqi/opt/anaconda3/lib/python3.8/site-packages/sklearn/gaussian_process/__init__.py)

# %%
# Visualize the result
plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')

plt.fill_between(xfit, yfit - dyfit, yfit + dyfit,
                 color='gray', alpha=0.2)
plt.xlim(0, 10);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-8494976ee5bf> in <module>
#       1 # Visualize the result
# ----> 2 plt.plot(xdata, ydata, 'or')
#       3 plt.plot(xfit, yfit, '-', color='gray')
#       4
#       5 plt.fill_between(xfit, yfit - dyfit, yfit + dyfit,
#
# NameError: name 'xdata' is not defined

# %% [markdown]
# # Density and Contour Plots
#
# use plt.contour for contour plots, plt.contourf for filled contour plots, and plt.imshow for showing images

# %%
def f(x, y): #z is contour levels
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y) #2d grids from 1d arrays
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='blue')
#neg are dashed, pos are solid

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy'); #want more lines to be drawn at 20 equally-spaced intervals
#cmap are color-coded

# %% [markdown]
# # Histograms, Binnings, and Density

# %%
plt.style.use('seaborn-white')
data=np.random.rand(1000)
plt.hist(data)
# Out:
# (array([103.,  90., 102.,  90.,  90.,  99., 103., 113.,  98., 112.]),
#  array([7.59463576e-04, 1.00624296e-01, 2.00489129e-01, 3.00353961e-01,
#         4.00218794e-01, 5.00083627e-01, 5.99948459e-01, 6.99813292e-01,
#         7.99678124e-01, 8.99542957e-01, 9.99407790e-01]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, bins=30, alpha=0.5,
         histtype='stepfilled', color='steelblue',
         edgecolor='none')
# Out:
# (array([32., 31., 40., 31., 29., 30., 35., 36., 31., 32., 25., 33., 35.,
#         27., 28., 35., 37., 27., 27., 41., 35., 38., 41., 34., 36., 34.,
#         28., 42., 38., 32.]),
#  array([7.59463576e-04, 3.40477411e-02, 6.73360186e-02, 1.00624296e-01,
#         1.33912574e-01, 1.67200851e-01, 2.00489129e-01, 2.33777406e-01,
#         2.67065684e-01, 3.00353961e-01, 3.33642239e-01, 3.66930516e-01,
#         4.00218794e-01, 4.33507071e-01, 4.66795349e-01, 5.00083627e-01,
#         5.33371904e-01, 5.66660182e-01, 5.99948459e-01, 6.33236737e-01,
#         6.66525014e-01, 6.99813292e-01, 7.33101569e-01, 7.66389847e-01,
#         7.99678124e-01, 8.32966402e-01, 8.66254679e-01, 8.99542957e-01,
#         9.32831234e-01, 9.66119512e-01, 9.99407790e-01]),
#  <a list of 1 Patch objects>)

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [193 192 189 216 210]
