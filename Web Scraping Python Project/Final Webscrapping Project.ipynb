# %%
import requests
from bs4 import BeautifulSoup #New Line

URL = 'https://www.monster.com/jobs/search/?q=Data-Science&where=Dallas'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser') #New Line
results = soup.find(id='ResultsContainer')

#look for Python jobs
python_jobs = results.find_all('h2', string=lambda text: 'python' in text.lower())
for p_job in python_jobs:
    link = p_job.find("a")["href"]
    print(p_job.text.strip())
    print(f"Apply here: {link}\n")
    
#all Data Science jobs in Dallas
job_elems = results.find_all('section', class_='card-content')
for job_elem in job_elems:
    title_elem = job_elem.find('h2', class_='title')
    company_elem = job_elem.find('div', class_='company')
    location_elem = job_elem.find('div', class_='location')
    if None in (title_elem, company_elem, location_elem): #ignores None
        continue                        
    print(title_elem.text.strip()) 
    print(company_elem.text.strip()) 
    print(location_elem.text.strip()) 
    print()
# Out:
# Python/AWS Developer
# Apply here: https://job-openings.monster.com/python-aws-developer-plano-tx-us-cognizant/220879645
#
# Data Scientist
# Cottonwood Financial
# Irving, TX
#
# Data Architect (Temporary Position)
# Southern Methodist University
# Dallas, TX
#
# Big Data Hadoop Engineer
# Company Confidential
# PLano, TX
#
# Senior Machine Learning Engineer
# Orangepeople LLC
# Plano, TX
#
# Python/AWS Developer
# Cognizant
# Plano, TX
#
# Principal Technology Architect
# HCSC
# Richardson, TX
#
# Data Engineer- No third parties plz
# Make Corp.
# DALLAS, TX
#
# DATA ENGINEER
# The Judge Group
# Irving, TX
#
# Software Architect
# Jobot
# Dallas, TX
#
# Machine Learning Manager
# InfoVision
# richardson, TX
#
# Senior Enterprise Desktop Engineer
# Watermark Digital
#
#
# Senior Data Scientist (Dallas, TX)
# Corporate
# Dallas, TX
#
# Data Scientist
# Academic Partnerships
# Dallas, TX
#
# Clinical Data Scientist
# HCA
# Dallas, TX
#
# Principal Data Scientist – 200000CC
# Tech-Connect
# Dallas, TX
#
# Enterprise Data Scientist (Dallas, TX, US)
# Parkland Hospital
# Dallas, TX
#
# Senior Data Scientist
# Maven Wave
# Dallas, TX
#
# Senior Data Scientist - USA
# o9 Solutions, Inc.
# Dallas, TX
#
# Data Scientist
# APN Software Services Inc.
# Dallas, TX
#
# Data Scientist
# Saatchi & Saatchi
# El Segundo, TX
#
# Data Scientist
# Mindlance
# Dallas, TX
#
# Data Scientist/IT Auditor
# Federal Reserve Bank (FRB)
# Dallas, TX
#
# Data Scientist Sr Associate
# JPMorgan Chase
# Plano, TX
#
# Data Scientist Sr Associate
# JPMorgan Chase Bank, N.A.
# Plano, TX
#
# Sr Data Scientist
# 7-Eleven
# Irving, TX
#
# Advanced Data Scientist - Predictive Maintenance
# Honeywell
# Richardson, TX
